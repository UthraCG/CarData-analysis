# %% [markdown]
# <a href="https://colab.research.google.com/github/UthraCG/CarData-analysis/blob/main/mobile_sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
path='/content/Flipkart Mobile sales.csv'
df=pd.read_csv(path)
df
# Out:
#       brand           model base_color processor screen_size  ROM  RAM  \
# 0     Apple       iPhone SE      Black     Water  Very Small   64    2
# 1     Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2     Apple       iPhone SE        Red     Water  Very Small   64    2
# 3     Apple       iPhone XR     Others       iOS      Medium   64    3
# 4     Apple       iPhone 12        Red   Ceramic      Medium  128    4
# ..      ...             ...        ...       ...         ...  ...  ...
# 425  Xiaomi     Redmi 6 Pro      Black  Qualcomm       Small   32    3
# 426  Xiaomi     Redmi 6 Pro        Red  Qualcomm       Small   64    4
# 427  Xiaomi      Mi 11 Lite     Others  Qualcomm       Large  128    6
# 428  Xiaomi   Redmi 8A Dual       Blue  Qualcomm      Medium   32    3
# 429  Xiaomi     Redmi 6 Pro       Blue  Qualcomm       Small   32    3
#
#      display_size  num_rear_camera  num_front_camera  battery_capacity  \
# ...

# %%
df.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  battery_capacity  ratings  \
# 0           4.7                1                 1              1800      4.5
# 1           5.4                2                 1              2815      4.5
# 2           4.7                1                 1              1800      4.5
# 3           6.1                1                 1              2942      4.6
# 4           6.1                2                 1              2815      4.6
#
#    num_of_ratings  sales_price  discount_percent   sales
# ...

# %%
df.shape
# Out:
# (430, 16)

# %%
df.describe()
# Out:
#               ROM         RAM  display_size  num_rear_camera  \
# count  430.000000  430.000000    430.000000       430.000000
# mean   105.748837    5.320930      6.369767         2.904651
# std     63.164064    2.182635      0.369549         0.952350
# min      8.000000    1.000000      4.700000         1.000000
# 25%     64.000000    4.000000      6.300000         2.000000
# 50%    128.000000    4.000000      6.500000         3.000000
# 75%    128.000000    6.000000      6.500000         4.000000
# max    512.000000   12.000000      7.600000         4.000000
#
#        num_front_camera  battery_capacity     ratings  num_of_ratings  \
# count        430.000000        430.000000  430.000000      430.000000
# mean           1.044186       4529.397674    4.339302    23567.944186
# std            0.227280        986.907252    0.151494    56096.277784
# min            1.000000       1800.000000    3.000000        4.000000
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()      # no need of null handling.
# Out:
# brand               0
# model               0
# base_color          0
# processor           0
# screen_size         0
# ROM                 0
# RAM                 0
# display_size        0
# num_rear_camera     0
# num_front_camera    0
# battery_capacity    0
# ratings             0
# num_of_ratings      0
# sales_price         0
# discount_percent    0
# sales               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430 entries, 0 to 429
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   brand             430 non-null    object
#  1   model             430 non-null    object
#  2   base_color        430 non-null    object
#  3   processor         430 non-null    object
#  4   screen_size       430 non-null    object
#  5   ROM               430 non-null    int64
#  6   RAM               430 non-null    int64
#  7   display_size      430 non-null    float64
#  8   num_rear_camera   430 non-null    int64
#  9   num_front_camera  430 non-null    int64
#  10  battery_capacity  430 non-null    int64
#  11  ratings           430 non-null    float64
#  12  num_of_ratings    430 non-null    int64
#  13  sales_price       430 non-null    int64
#  14  discount_percent  430 non-null    float64
#  15  sales             430 non-null    float64
# ...

# %%
df['brand'].unique()
# Out:
# array(['Apple', 'Poco', 'Realme', 'Samsung', 'Xiaomi'], dtype=object)

# %%
df['brand'].value_counts()
# Out:
# brand
# Realme     138
# Samsung    119
# Xiaomi      61
# Apple       56
# Poco        56
# Name: count, dtype: int64

# %%
df['model'].unique()
# Out:
# array(['iPhone SE', 'iPhone 12 Mini', 'iPhone XR', 'iPhone 12',
#        'iPhone 8', 'iPhone 7 Plus', 'C3', 'M3', 'M2 Reloaded', 'X3 Pro',
#        'M3 Pro 5G', 'M2 Pro', 'F3 GT', 'X3', 'F1', 'M2', 'X2', 'C20',
#        'C11 2021', 'C21Y', 'Narzo 30 5G', 'C21', 'Narzo 30', '8s 5G',
#        'Narzo 30A', '8 5G', '8 Pro', 'C15', '8', 'GT Master Edition',
#        'X7 5G', '7', 'Narzo 30 Pro 5G', 'C12', 'C11', 'X7 Max', 'GT 5G',
#        '5 Pro', '3i', 'Narzo 20 Pro', '7 Pro', 'X3 SuperZoom',
#        'X7 Pro 5G', 'C2', '6', '6i', 'C25', 'Narzo 20', 'Narzo 10A',
#        'Narzo 20A', 'Narzo 10', 'Galaxy F22', 'Galaxy F12', 'M02s',
#        'Galaxy M02', 'Galaxy A22', 'Galaxy A52s 5G', 'Galaxy M32',
#        'Galaxy Z Flip3 5G', 'Galaxy A22 5G', 'Galaxy A21s', 'Galaxy A03s',
#        'Galaxy M31', 'Galaxy A51', 'Galaxy A72', 'Galaxy A12',
#        'Galaxy F62', 'Galaxy A31', 'Galaxy A52', 'Galaxy F02s',
#        'Galaxy M11', 'Galaxy F41', 'Galaxy A71', 'Galaxy Note 20',
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df['model'].value_counts())
# Out:
# model
# iPhone XR                  18
# iPhone 12                  17
# iPhone 12 Mini             16
# GT Master Edition           9
# X3                          9
# M3                          9
# M2 Pro                      9
# Galaxy A21s                 7
# Narzo 30                    6
# Galaxy F62                  6
# 8 5G                        6
# 8 Pro                       6
# Galaxy F41                  6
# 8                           6
# 7 Pro                       6
# X7 Max                      6
# X3 SuperZoom                6
# 5 Pro                       6
# Galaxy F12                  6
# Mi 11 Lite                  6
# 3i                          6
# Redmi Note 7 Pro            6
# Redmi 6 Pro                 6
# C3                          6
# Galaxy A03s                 6
# X3 Pro                      6
# F3 GT                       6
# Galaxy F02s                 5
# Galaxy A20s                 5
# Galaxy A51                  5
# Redmi Note 6 Pro            5
# ...

# %%
df['base_color'].unique()     #	brand	model	base_color	processor	screen_size
# Out:
# array(['Black', 'Red', 'Others', 'Blue', 'White', 'Green', 'Purple',
#        'Yellow', 'Gold', 'Bronze', 'Silver', 'Gray'], dtype=object)

# %%
df['base_color'].value_counts()
# Out:
# base_color
# Blue      117
# Black     112
# White      44
# Silver     32
# Others     28
# Green      24
# Red        21
# Gray       20
# Yellow     11
# Gold       11
# Purple      5
# Bronze      5
# Name: count, dtype: int64

# %%
df['processor'].unique()
# Out:
# array(['Water', 'Ceramic', 'iOS', 'MediaTek', 'Qualcomm', 'Others',
#        'Exynos'], dtype=object)

# %%
df['processor'].value_counts()
# Out:
# processor
# Qualcomm    168
# MediaTek    144
# Exynos       53
# Ceramic      33
# iOS          12
# Water        11
# Others        9
# Name: count, dtype: int64

# %%
df['screen_size'].unique()
# Out:
# array(['Very Small', 'Small', 'Medium', 'Large', 'Very Large'],
#       dtype=object)

# %%
df['screen_size'].value_counts()
# Out:
# screen_size
# Large         242
# Medium        146
# Small          34
# Very Small      4
# Very Large      4
# Name: count, dtype: int64

# %%
df['RAM'].value_counts()
# Out:
# RAM
# 4     133
# 6     114
# 8      88
# 3      60
# 2      21
# 12     12
# 1       2
# Name: count, dtype: int64

# %%
df['ROM'].value_counts()
# Out:
# ROM
# 128    192
# 64     138
# 32      54
# 256     38
# 16       5
# 8        2
# 512      1
# Name: count, dtype: int64

# %%
df['ratings'].unique()
# Out:
# array([4.5, 4.6, 4.3, 4.4, 4.2, 4.1, 4. , 3.9, 3. , 3.8])

# %%
df['ratings'].value_counts()
# Out:
# ratings
# 4.3    181
# 4.4     79
# 4.5     55
# 4.2     55
# 4.6     37
# 4.0     10
# 4.1      8
# 3.9      3
# 3.0      1
# 3.8      1
# Name: count, dtype: int64

# %%
dd=df[df['ratings']==4.6]
dd.reset_index(inplace=True)
dd
# Out:
#     index    brand       model base_color processor screen_size  ROM  RAM  \
# 0       3    Apple   iPhone XR     Others       iOS      Medium   64    3
# 1       4    Apple   iPhone 12        Red   Ceramic      Medium  128    4
# 2       5    Apple   iPhone 12       Blue   Ceramic      Medium   64    4
# 3       6    Apple   iPhone 12      White   Ceramic      Medium  128    4
# 4       7    Apple   iPhone 12      Green   Ceramic      Medium   64    4
# 5       8    Apple   iPhone 12       Blue   Ceramic      Medium  128    4
# 6       9    Apple   iPhone 12      Black   Ceramic      Medium  128    4
# 7      11    Apple   iPhone 12      Green   Ceramic      Medium  128    4
# 8      13    Apple   iPhone 12       Blue   Ceramic      Medium  256    4
# 9      15    Apple   iPhone XR      White     Water      Medium  128    3
# 10     16    Apple   iPhone 12        Red   Ceramic      Medium   64    4
# 11     17    Apple   iPhone 12      Black   Ceramic      Medium   64    4
# ...

# %%
df.value_counts('sales_price')
# Out:
# sales_price
# 14999     22
# 15999     14
# 8999      12
# 9999      12
# 16999     11
#           ..
# 13400      1
# 13399      1
# 12900      1
# 12749      1
# 157999     1
# Name: count, Length: 141, dtype: int64

# %%
df.sort_values('discount_percent',ascending=False)
# Out:
#      brand  model  base_color  processor  screen_size  ROM  RAM  display_size  \
# 332      3     48           1          1            2   64    4           5.6
# 367      3     60           0          1            1  128    8           6.1
# 315      3     33           0          1            1  128    4           6.4
# 329      3     33           6          1            1  128    4           6.4
# 429      4     91           1          4            2   32    3           5.8
# ..     ...    ...         ...        ...          ...  ...  ...           ...
# 266      3     51           0          2            0   32    2           6.5
# 271      3     54           1          3            1  128    8           6.4
# 398      4    102           1          4            1  128    6           6.3
# 270      3     54           0          3            1  128    6           6.4
# 417      4     78           0          4            0  128    8           6.7
#
# ...

# %%
import plotly.express as px
fig=px.scatter(df,x='sales_price',y='ratings',color='sales_price',hover_name='brand')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig1=px.pie(df,names='brand',values='sales_price')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig2=px.sunburst(df,path=['brand','model','screen_size'],values='sales_price')
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_cate=df.select_dtypes(exclude=['int64',"float64"])
df_cate
# Out:
#       brand           model base_color processor screen_size
# 0     Apple       iPhone SE      Black     Water  Very Small
# 1     Apple  iPhone 12 Mini        Red   Ceramic       Small
# 2     Apple       iPhone SE        Red     Water  Very Small
# 3     Apple       iPhone XR     Others       iOS      Medium
# 4     Apple       iPhone 12        Red   Ceramic      Medium
# ..      ...             ...        ...       ...         ...
# 425  Xiaomi     Redmi 6 Pro      Black  Qualcomm       Small
# 426  Xiaomi     Redmi 6 Pro        Red  Qualcomm       Small
# 427  Xiaomi      Mi 11 Lite     Others  Qualcomm       Large
# 428  Xiaomi   Redmi 8A Dual       Blue  Qualcomm      Medium
# 429  Xiaomi     Redmi 6 Pro       Blue  Qualcomm       Small
#
# [430 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for i in df_cate.columns:
     df[i]=le.fit_transform(df_cate[i])
     print(i)
df
# Out:
# brand
# model
# base_color
# processor
# screen_size
#      brand  model  base_color  processor  screen_size  ROM  RAM  display_size  \
# 0        0    117           0          5            4   64    2           4.7
# 1        0    114           8          0            2   64    4           5.4
# 2        0    117           8          5            4   64    2           4.7
# 3        0    118           6          6            1   64    3           6.1
# 4        0    113           8          0            1  128    4           6.1
# ..     ...    ...         ...        ...          ...  ...  ...           ...
# 425      4     91           0          4            2   32    3           5.8
# 426      4     91           8          4            2   64    4           5.8
# 427      4     76           6          4            0  128    6           6.5
# 428      4     93           1          4            1   32    3           6.2
# ...

# %%
corr=df.corr()
corr
# Out:
#                      brand     model  base_color  processor  screen_size  \
# brand             1.000000 -0.248286   -0.148972   0.132482    -0.170389
# model            -0.248286  1.000000    0.130368   0.122789     0.275462
# base_color       -0.148972  0.130368    1.000000  -0.001256     0.049771
# processor         0.132482  0.122789   -0.001256   1.000000     0.069197
# screen_size      -0.170389  0.275462    0.049771   0.069197     1.000000
# ROM              -0.136110  0.136181    0.071786  -0.106651     0.081554
# RAM               0.165226 -0.070618    0.018976   0.054517    -0.161781
# display_size      0.302827 -0.319216   -0.083042   0.086951    -0.713174
# num_rear_camera   0.179594 -0.378151   -0.013668  -0.079011    -0.491259
# num_front_camera  0.082684  0.154792    0.040739   0.169497     0.004159
# battery_capacity  0.317391 -0.412231   -0.134009  -0.103624    -0.623638
# ratings          -0.471712  0.341180    0.087344   0.045105     0.286388
# ...

# %%
import seaborn as sns
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# People are ready to order the mobiles like topend and middle level.
# in high end model mobiles like iphone and samsung with 128 GB RAM. mostly chosen color is black.
#
# people of budget 20k is going for mostly realme. but company can focus on poco. which is growing fast with good dimensions, rom, ram and price.
#
# Sales is purely depends on sales price and number of ratings. So ii n eCommerce the people purely depend on the ratings given by the people.
